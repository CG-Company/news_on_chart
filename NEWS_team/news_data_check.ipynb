# %%
import pandas as pd

# 파일 경로를 지정하세요
parquet_path = r".\1-10_ctock_news_data\news_analysis_000660.parquet"

# Parquet 파일 읽기
df = pd.read_parquet(parquet_path)

# 데이터의 상위 5개 행 확인
print(df.head())

# 데이터의 전체 컬럼 및 정보 확인
print(df.info())

selected_df = df[df['is_selected'] == True]
selected_df

# published_at 열이 비어있는(결측치) 행의 갯수 출력
num_missing = df['published_at'].isna().sum()
print(f"published_at 열이 채워지지 않은 행의 갯수: {num_missing}")
# Out:
#    ticker published_at                                             title  \
# 0  000660   2025-06-26  [박진섭의 황금선] 美 IDM 기업과 차량용 반도체 설계 공급 계약 체결 '에이직랜드'
# 1  000660   2025-06-26                     [특징주]엔비디아 신고가에 SK하이닉스, 3%대 상승
# 2  000660   2025-06-26                    3100선 내준 코스피 외인 기관 '팔자'에 숨 고르기
# 3  000660   2025-06-26                 엔비디아 최고가 경신 업황 회복 기대감에 반도체주 동반 상승
# 4  000660   2025-06-26            “매일 요즘만 같았으면” 출퇴근길 즐겁게 하는 주식시장, 그중 으뜸은
#
#                                                  url publisher_name  \
# 0  http://news.moneytoday.co.kr/view/mtview.php?n...          머니투데이
# 1  https://view.asiae.co.kr/article/2025062609520...          아시아경제
# 2  https://view.asiae.co.kr/article/2025062609472...          아시아경제
# 3  http://news.moneytoday.co.kr/view/mtview.php?n...          머니투데이
# 4               http://www.mk.co.kr/article/11352642           매일경제
#
#    is_selected summary keywords
# 0        False    None     None
# 1        False    None     None
# ...
