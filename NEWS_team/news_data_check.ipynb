# %%
import pandas as pd

# 파일 경로를 지정하세요
parquet_path = r".\macro_news_data\macro_daily_news.parquet"

# Parquet 파일 읽기
df = pd.read_parquet(parquet_path)

# 데이터의 상위 5개 행 확인
print(df.head())

# 데이터의 전체 컬럼 및 정보 확인
print(df.info())

selected_df = df[df['is_selected'] == True]
selected_df

# published_at 열이 비어있는(결측치) 행의 갯수 출력
num_missing = df['published_at'].isna().sum()
print(f"published_at 열이 채워지지 않은 행의 갯수: {num_missing}")
# Out:
#    ticker       date                                          title  \
# 0  000000 2023-06-01                                 이달 美금리 동결론 재부상
# 1  000000 2023-06-02                         엇갈린 美고용실적  연준 금리동결에 무게
# 2  000000 2023-06-03  “동결 인상” 6월 FOMC 금리 전망 두고 ‘갈팡질팡’ 증시 3천 전망도 나왔다
# 3  000000 2023-06-04                       시장 우려 줄었지만...CPI FOMC 경계
# 4  000000 2023-06-05                    달러 풀어서 원화값 방어 외환보유액 석달만에 감소
#
#                                              summary  \
# 0  이달 미국 연방준비제도(Fed)의 금리 동결 가능성이 재부상하고 있다는 보도가 나왔...
# 1  미국의 고용 실적이 엇갈리면서 연방준비제도(Fed)의 금리 동결 가능성이 높아지고 ...
# 2  6월 FOMC(연방공개시장위원회)에서 기준금리 동결 여부에 대한 불확실성이 커지고 ...
# 3  시장의 우려가 줄어들고 있지만, 소비자 물가 지수(CPI)와 미국 연방공개시장위원회...
# 4  한국의 외환보유액이 석 달 만에 감소하면서, 정부가 달러를 풀어 원화 가치를 방어하...
#
#                                keywords                                   url  \
# 0   미국 금리, 금리 동결, 통화정책, 글로벌 금융시장, 한국 경제  http://www.mk.co.kr/article/10750658
# 1  미국 고용, 연준 금리, 금리 동결, 한국 주식시장, 외국인 투자  http://www.mk.co.kr/article/10751661
# 2              기준금리, FOMC, 증시, 미국, 한국시장  http://www.mk.co.kr/article/10751773
# 3  소비자 물가 지수, FOMC, 금리 정책, 인플레이션, 시장 우려  http://www.mk.co.kr/article/10752024
# 4        외환보유액, 원화가치, 달러, 경제불안, 한국 주식시장  http://www.mk.co.kr/article/10753207
#
#   publisher
# 0      매일경제
# 1      매일경제
# 2      매일경제
# 3      매일경제
# 4      매일경제
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ticker     748 non-null    object
#  1   date       748 non-null    datetime64[ns]
#  2   title      748 non-null    object
#  3   summary    748 non-null    object
#  4   keywords   748 non-null    object
#  5   url        748 non-null    object
#  6   publisher  748 non-null    object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 41.0+ KB
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\anaconda3\envs\news\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'is_selected'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 15
#      12 # 데이터의 전체 컬럼 및 정보 확인
#      13 print(df.info())
# ---> 15 selected_df = df[df['is_selected'] == True]
#      16 selected_df
#      18 # published_at 열이 비어있는(결측치) 행의 갯수 출력
#
# File c:\anaconda3\envs\news\lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File c:\anaconda3\envs\news\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'is_selected'
